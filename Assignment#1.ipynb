# %%
student_name = "Amir"
student_city = "karachi"
student_age= 21
student_status = True
print(f"{student_name} is the name of student and live in {student_city} age is {student_age} and status is {student_status}")
# Out:
# Amir is the name of student and live in karachi age is 21 and status is True

# %%
student_name = "Amir"
student_height = 5.6
student_age= 21
student_status = True
print(f"{type(student_name)} is the datatype of student_name and {type(student_age)}is the datatype of student_age and {type(student_height)} is the datatype of student_height and  {type(student_status)} is the datatype of student_status")
# Out:
# <class 'str'> is the datatype of student_name and <class 'int'>is the datatype of student_age and <class 'float'> is the datatype of student_height and  <class 'bool'> is the datatype of student_status

# %%
a = 10
b = 20
c = a+b 
d = a*b
e = a-b 
f = a/b
i = a%b
g = a**b

# %%
math = 50 
computer = 87
biology =37
total = math + computer + biology
avegra = (math + computer + biology)/3
print(f"the total is {total} and average is {avegra}")
# Out:
# the total is 174 and average is 58.0

# %%
product_price = 200
product_quantity = 14
total = product_price*product_quantity
print(f"your total bill will be {total}")
# Out:
# your total bill will be 2800

# %%
length = 20
width =30
area = length*width
perimeter = 2*(length + width)
print(f"the area is {area} and perimeter is {perimeter}")
# Out:
# the area is 600 and perimeter is 100

# %%
time = 250
hr = time // 60
minutes = (time / 60 -hr) * 100
print(f"the remainig time is {hr} hr and {minutes} min only !")
# Out:
# the remainig time is 4 hr and 16.666666666666696 min only !

# %%
student_marks = 50
student_attendance = 76
if (student_marks >= 50 and student_attendance >= 75): 
    print("eligible")
# Out:
# eligible

# %%
a = True
b = False
print(a and b)
print(a or b)
print(not a)
print(not b)
# Out:
# False
# True
# False
# True

# %%
student_name = "Amir"
student_age= 21
student_marks = 50
student_attendance = 76
math = 50 
computer = 87
biology =37
total = math + computer + biology
avegra = (math + computer + biology)/3
print(f"{student_name} is the name of student and age is {student_age} and student marks is {student_mars} and student marks is {student_attendance}")
print(f"the total is {total} and average is {avegra}")
cond1 = student_marks >= 50
cond2 = student_attendance >= 75
cond1 and c
# Out:
# the total is 174 and average is 58.0
# eligible
